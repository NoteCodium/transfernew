# %% [markdown]
# [1](/Users/tarunmali/yTM/code/cpp/1/ADC/1Algorithms/70Mathematics/1median/0Definition.ipynb)

# %% [markdown]
# [2](/Users/tarunmali/yTM/code/cpp/1/ADC/1Algorithms/98PriorityQueue/5stream-twoheaps-multiset-pbds/1Median.ipynb)
