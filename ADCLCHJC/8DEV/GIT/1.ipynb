# %% [markdown]
# # vscode
#
# u→ untracked
#
# m → modified

# %% [markdown]
# main master default lafda, also see the default setup

# %% [markdown]
# # git clone
# //create new branch and checkout to it
# git checkout -b branchName
# (cbT)

# %% [markdown]
# git switch -c branchName
#  (sc)

# %% [markdown]
# ![{B656F507-4054-475A-818C-712CC7250558}.png](attachment:{B656F507-4054-475A-818C-712CC7250558}.png)
#
# remember two of the codes used to do the same stuff

# %% [markdown]
# git branch
# ![{1D175D5B-DD75-4B7F-BC4F-84BAEA2A8775}.png](attachment:{1D175D5B-DD75-4B7F-BC4F-84BAEA2A8775}.png)

# %% [markdown]
# global braches ALSO
# ![{7B0CE66A-3CDA-4F29-8B50-A35BC9C82C57}.png](attachment:{7B0CE66A-3CDA-4F29-8B50-A35BC9C82C57}.png)

# %% [markdown]
# //without creating a new branch
# ![{2EF9F68A-7BA9-4B7B-8369-A3FF9F1828FA}.png](attachment:{2EF9F68A-7BA9-4B7B-8369-A3FF9F1828FA}.png)

# %% [markdown]
# deleting a branch
# git branch -d branchName

# %% [markdown]
# # Pushing a branch
# git push origin branchName
# (doubt)

# %% [markdown]
# ![{4DDFA0DC-AB0A-4CAE-8946-F4E98FE29F6C}.png](attachment:{4DDFA0DC-AB0A-4CAE-8946-F4E98FE29F6C}.png)

# %% [markdown]
# ![{FA60FACB-CE1F-4CE5-9CC6-8990815B7FC7}.png](attachment:{FA60FACB-CE1F-4CE5-9CC6-8990815B7FC7}.png)

# %% [markdown]
# ![{34190074-C4C5-4A76-91F1-89EFC27FE014}.png](attachment:{34190074-C4C5-4A76-91F1-89EFC27FE014}.png)

# %% [markdown]
# # Workflow
# git add fileName
# //adding files to track
# //They will be in staging area now
# git commit -m "message"
# //doubt why the flag
# git push

# %% [markdown]
# git status
# ![image.png](attachment:image.png)

# %% [markdown]
# Suppose we created a file

# %% [markdown]
# ![{48643ED1-B4F2-46D0-B83A-C0D644BC18A7}.png](attachment:{48643ED1-B4F2-46D0-B83A-C0D644BC18A7}.png)

# %% [markdown]
# suppose we git added the file

# %% [markdown]
# ![{F5A57248-40EB-4E2D-9B91-351EB89850BF}.png](attachment:{F5A57248-40EB-4E2D-9B91-351EB89850BF}.png)

# %% [markdown]
# # To unstage
# git rm --cached fileName

# %% [markdown]
# ![{91119B03-A916-45E0-AFB7-AC867F311B12}.png](attachment:{91119B03-A916-45E0-AFB7-AC867F311B12}.png)

# %% [markdown]
# whats the difference bw git log and git status

# %% [markdown]
# git commit -m "message"

# %% [markdown]
# suppose we use
# git commit

# %% [markdown]
# ![{62E6FD73-5969-4290-AA4B-D760C658C738}.png](attachment:{62E6FD73-5969-4290-AA4B-D760C658C738}.png)

# %% [markdown]
# doubt
# ![{183493F6-B39E-44DB-A446-C85516000F80}.png](attachment:{183493F6-B39E-44DB-A446-C85516000F80}.png)

# %% [markdown]
# ![{E8D048B8-0D65-4EF4-8085-E26A3898E0C4}.png](attachment:{E8D048B8-0D65-4EF4-8085-E26A3898E0C4}.png)

# %% [markdown]
# ![{30DB2FC2-9BF0-4865-B846-EC9BF000C0A0}.png](attachment:{30DB2FC2-9BF0-4865-B846-EC9BF000C0A0}.png)

# %% [markdown]
# -hyphen
