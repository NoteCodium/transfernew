# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# nptel cp course

# %% [markdown]
# navneet course

# %% [markdown]
# Everything of the course at single place
#
# https://docs.google.com/document/d/1TMlTSffhY-CG8TuX52d5tnAn6zjVzXqQ4JZ0pwX4hvo/edit?tab=t.0
