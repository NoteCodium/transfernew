# %% [markdown]
# NumberStore
#
# insert
# search

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Vivek
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# continue from 4:00
