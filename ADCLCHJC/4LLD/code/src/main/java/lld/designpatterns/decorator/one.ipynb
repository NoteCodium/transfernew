# %% [markdown]
# ![{7AD72206-6A2E-48E2-B655-FFD268AE47B6}.png](attachment:{7AD72206-6A2E-48E2-B655-FFD268AE47B6}.png)

# %% [markdown]
# File reader read it
# Buffer reader creates a buffer in the ram
# Decorating the functionalityies
# We get a new complex functionality
