# %% [markdown]
# neetcode
#
# ppa
#
# Striver
#
# one doubt in merging

# %% [markdown]
# https://leetcode.com/problems/reorder-list/description/

# %% [markdown]
# ![image.png](attachment:image.png)
