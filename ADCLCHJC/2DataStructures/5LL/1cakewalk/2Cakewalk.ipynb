// %% [markdown]
// # Traversing

// %% [markdown]
// https://practice.geeksforgeeks.org/problems/count-nodes-of-linked-list/1

// %%
//finding len
if(!head) return 0;
Node* curr=head;
while(curr){
	curr=curr->next;
	len++;
}

// %%
//search
if(!head) return 0;
Node* curr=head;
while(curr){
	if(curr->data==k) return 1;
	curr=curr->next;
}
return 0;
