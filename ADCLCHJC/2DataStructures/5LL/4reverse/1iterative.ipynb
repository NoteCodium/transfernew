// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// at some time, let this be the configuration

// %%
tmp=curr->next;
curr->next=prev;
prev=curr;
curr=tmp;

// %%
Node * curr=head;
Node* prev= nullptr;
while(curr){
	tmp=curr->next;
	curr->next=prev;
	prev=curr;
	curr=tmp;
}
return prev;
