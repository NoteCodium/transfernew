# %% [markdown]
# https://www.geeksforgeeks.org/problems/binary-tree-to-bst/1
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
