# %% [markdown]
# Questions
#
# q. Largest palindrome substring in a string or vector
# https://leetcode.com/problems/longest-palindromic-substring/description/
#
# https://youtu.be/IvakBbsAhUU?si=5M3pSwN9AABTzGI2
#
# with manachar
