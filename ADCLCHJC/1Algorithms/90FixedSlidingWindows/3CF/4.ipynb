# %% [markdown]
# https://codeforces.com/contest/1341/problem/B

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. in the first iteration mark all peaks as 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
