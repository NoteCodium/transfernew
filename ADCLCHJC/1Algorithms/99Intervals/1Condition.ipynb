# %% [markdown]
# no intersection

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# if intersection

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
