# %% [markdown]
# nge

# %% [markdown]
# The stack will be decreasing from bottom to top of the stack, because any time an element which came is greater then the top element of the stack, it is their nge

# %%
stack<int> st;
st.push(0);
vector<int> nge(n,n);
for(int i=1;i<n;i++){
  while(!st.empty() and v[i]>v[st.top()]){
//the current element which came is greater then the top element, 
//as long as it is greater then the top element of stack, it will be nge of that element
    nge[st.top()]=i;
    st.pop();
  }
  st.push(i);
}

# %% [markdown]
# NGE left ke lie

# %%
st.push(n-1);
for(int i=n-2;i>=0;i--)

# %% [markdown]
# Circular

# %%
for(int i=1;i<2*n;i++)
//use i%n everywhere
