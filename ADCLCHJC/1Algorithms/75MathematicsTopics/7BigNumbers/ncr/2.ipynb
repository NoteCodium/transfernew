# %% [markdown]
# do them from maths

# %% [markdown]
# https://leetcode.com/problems/unique-paths/
# https://cses.fi/problemset/task/1638/

# %% [markdown]
# 2. Do the normal problem with maths
# 3. do with changed steps
# 4. now mix 2 and 3  Titan
