# %% [markdown]
# https://codeforces.com/problemset/problem/1166/C

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# negative numbers do not have any impact
