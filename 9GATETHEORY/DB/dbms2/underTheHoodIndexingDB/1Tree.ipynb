# %% [markdown]
# ![{DF31CB45-89FE-4595-BBA5-DFA43F4B1F36}.png](attachment:{DF31CB45-89FE-4595-BBA5-DFA43F4B1F36}.png)

# %% [markdown]
# order so we can have <= and >= concept

# %% [markdown]
# ordered map used to have balanced bst under the hood

# %% [markdown]
# uber example
# ![{B5135438-476F-46F9-937A-002AB26568F6}.png](attachment:{B5135438-476F-46F9-937A-002AB26568F6}.png)

# %% [markdown]
# In b tree we have 3 pointers,
# ![{57914E2C-3149-4855-8463-BC26B125302A}.png](attachment:{57914E2C-3149-4855-8463-BC26B125302A}.png)

# %% [markdown]
# Using these indexing makes the process of addition, updation and ddeltion of a new data entry costly

# %% [markdown]
# ![{5B17F53A-9EFD-4FCF-BEAA-FF2735219161}.png](attachment:{5B17F53A-9EFD-4FCF-BEAA-FF2735219161}.png)

# %% [markdown]
# basics
# ![{D515E653-8910-4967-9FDB-4D3CCCF7ACCF}.png](attachment:{D515E653-8910-4967-9FDB-4D3CCCF7ACCF}.png)

# %% [markdown]
# the only differene is this data will be present in harddisk and not in ram
