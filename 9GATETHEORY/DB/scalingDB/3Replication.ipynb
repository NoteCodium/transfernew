# %% [markdown]
# Leader Leader

# %% [markdown]
# ![{58EA4B40-952E-4A14-9566-8F90D6D7709E}.png](attachment:{58EA4B40-952E-4A14-9566-8F90D6D7709E}.png)

# %% [markdown]
# Both serving different parts of the word and sync happens every few unit of time
