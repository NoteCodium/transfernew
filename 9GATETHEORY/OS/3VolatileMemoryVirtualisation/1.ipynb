# %% [markdown]
# to perceive more memory than is physically installed on the computer.

# %% [markdown]
# ![{9EE494D0-FA2E-40AE-AA71-DF86380C0B0F}.png](attachment:{9EE494D0-FA2E-40AE-AA71-DF86380C0B0F}.png)

# %% [markdown]
# always start from 0?

# %% [markdown]
# ![{9180CC2F-DCF1-45D7-AE99-475F9F59B0E4}.png](attachment:{9180CC2F-DCF1-45D7-AE99-475F9F59B0E4}.png)

# %% [markdown]
# 1. Every process has a special register called the base register which stores the base address of the process
# 2. limit register which store bound address of a process
# 3. These registers  are part of memory management unit

# %% [markdown]
# 4. When a address goes out of limit register it
#
# ⇒generate a trap
#
# which results
#
# ⇒ segmentation error

# %% [markdown]
# ![{F4AE3157-610A-43FC-A27C-479E8842F9FF}.png](attachment:{F4AE3157-610A-43FC-A27C-479E8842F9FF}.png)

# %% [markdown]
# ![{7E138B80-041E-4756-9DCC-4CF3F95BBB72}.png](attachment:{7E138B80-041E-4756-9DCC-4CF3F95BBB72}.png)
