# %% [markdown]
# Compaction

# %% [markdown]
# ![{6DBE0384-BB60-4260-9F84-389462ED943B}.png](attachment:{6DBE0384-BB60-4260-9F84-389462ED943B}.png)
#
# ?

# %% [markdown]
# ?
#
# ![{64CA4B7F-EB25-4A47-91DA-902146A0C202}.png](attachment:{64CA4B7F-EB25-4A47-91DA-902146A0C202}.png)
