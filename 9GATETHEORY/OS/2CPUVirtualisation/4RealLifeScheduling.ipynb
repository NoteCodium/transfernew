# %% [markdown]
# # Multilevel feedback queue

# %% [markdown]
# ![{06037E0E-5974-4FC5-8D6D-930C66450287}.png](attachment:{06037E0E-5974-4FC5-8D6D-930C66450287}.png)

# %% [markdown]
# These will have their separate schedular

# %% [markdown]
# inter queue movement is allaowd
