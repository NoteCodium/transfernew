# %% [markdown]
# ipv6 uses 128 bit

# %% [markdown]
# 8 groups of 4 hexadecimal digits

# %% [markdown]
# 1 hexadecimal digit=== 4 bits

# %% [markdown]
# 1 hexadecimal digit=== 4 bits
# 4 hexadecimal digit=== 16 bits
# 8 groups of 4 hexadecimal digit== 128 bits

# %% [markdown]
# 0-e=== 2^16

# %% [markdown]
# network id+ host id

# %% [markdown]
# ip addresses are divided into 5 classes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Firewall
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
