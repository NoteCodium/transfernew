# %% [markdown]
# collision domain and broadcast domain

# %% [markdown]
# circuit switching
# telephone, already connected

# %% [markdown]
# packet switching (OSI)
# packets

# %% [markdown]
# # Types of packet switching
# ## datagram switching
# conectionless
#
# vs
#
#
# ## virtual circuit switching

# %% [markdown]
# message switching
# hop by hop delivery

# %% [markdown]
# # Framing
# ![image.png](attachment:image.png)

# %% [markdown]
# esc ,flag in data: byte stuffing
